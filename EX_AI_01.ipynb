# %% [markdown]
# <a href="https://colab.research.google.com/github/vskChaithanya/Explanable_AI_Practical/blob/main/EX_AI_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import shap
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %% [markdown]
# #Problem-1

# %%
d1=pd.read_excel("/content/Car_Sales.xlsx")
d1
# Out:
#    Number of TV Ads (x)  Number of Cars Sold (y)
# 0                     1                       14
# 1                     3                       24
# 2                     2                       18
# 3                     1                       17
# 4                     3                       27

# %%
y1=d1["Number of Cars Sold (y)"]
y1
# Out:
# 0    14
# 1    24
# 2    18
# 3    17
# 4    27
# Name: Number of Cars Sold (y), dtype: int64

# %%
data=pd.read_excel("/content/Marketing_Dataset.xlsx")
data
# Out:
#      youtube  facebook  newspaper  sales
# 0     276.12     45.36      83.04  26.52
# 1      53.40     47.16      54.12  12.48
# 2      20.64     55.08      83.16  11.16
# 3     181.80     49.56      70.20  22.20
# 4     216.96     12.96      70.08  15.48
# ..       ...       ...        ...    ...
# 195    45.84      4.44      16.56   9.12
# 196   113.04      5.88       9.72  11.64
# 197   212.40     11.16       7.68  15.36
# 198   340.32     50.40      79.44  30.60
# 199   278.52     10.32      10.44  16.08
#
# [200 rows x 4 columns]

# %%
y=data["sales"]
y
# Out:
# 0      26.52
# 1      12.48
# 2      11.16
# 3      22.20
# 4      15.48
#        ...
# 195     9.12
# 196    11.64
# 197    15.36
# 198    30.60
# 199    16.08
# Name: sales, Length: 200, dtype: float64

# %%
x=data.drop("sales",axis=1)
x
# Out:
#      youtube  facebook  newspaper
# 0     276.12     45.36      83.04
# 1      53.40     47.16      54.12
# 2      20.64     55.08      83.16
# 3     181.80     49.56      70.20
# 4     216.96     12.96      70.08
# ..       ...       ...        ...
# 195    45.84      4.44      16.56
# 196   113.04      5.88       9.72
# 197   212.40     11.16       7.68
# 198   340.32     50.40      79.44
# 199   278.52     10.32      10.44
#
# [200 rows x 3 columns]

# %%
model=LinearRegression()
model.fit(x,y)
# Out:
# LinearRegression()

# %%
print('Intercept: ', model.intercept_)
print('Coefficients: ', model.coef_)
# Out:
# Intercept:  3.508091507902039
# Coefficients:  [ 0.04568867  0.18874357 -0.00073692]

# %% [markdown]
# #Regression Model Building Using SHAP

# %%
explainer = shap.Explainer(model,x)
shap_values = explainer(x)
shap_values
# Out:
# .values =
# array([[ 4.73760397e+00,  3.35253886e+00, -3.32089991e-02],
#        [-5.43817569e+00,  3.69227729e+00, -1.18973711e-02],
#        [-6.93493639e+00,  5.18712640e+00, -3.32974291e-02],
#        [ 4.28249003e-01,  4.14526187e+00, -2.37469900e-02],
#        [ 2.03466249e+00, -2.76275294e+00, -2.36585600e-02],
#        [-7.40096078e+00,  5.86660327e+00, -3.83379386e-02],
#        [-4.72543251e+00,  2.22007742e+00,  7.20350712e-03],
#        [-1.28781729e+00, -7.69620798e-01,  1.77266761e-02],
#        [-7.40644342e+00, -4.73323585e+00,  2.71002553e-02],
#        [ 3.07636408e+00, -4.61998971e+00,  9.23739693e-03],
#        [-4.25392548e+00, -3.89521439e+00,  6.58449718e-03],
#        [ 3.89327742e+00,  2.26945274e-01,  2.44473555e-02],
#        [-6.57308216e+00,  2.74100968e+00, -3.02908094e-02],
#        [-2.53237655e+00, -3.48752827e+00,  2.16175958e-02],
#        [ 3.31211759e+00,  2.24272665e+00, -1.26932410e-02],
# ...

# %%
shap.plots.waterfall(shap_values[0])

# %%
shap.plots.waterfall(shap_values[1])

# %%
shap.plots.waterfall(shap_values[2])

# %%
shap.initjs()
shap.plots.force(shap_values[0])
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# ...

# %%
shap.initjs()
shap.plots.force(shap_values[1])
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# ...

# %%
shap.initjs()
shap.plots.force(shap_values[2])
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# ...
